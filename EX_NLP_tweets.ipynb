# %%
import requests
import re
from bs4 import BeautifulSoup as bs
import nltk
from nltk.corpus import stopwords
from textblob import TextBlob
import tweepy
import matplotlib.pylab as plt
plt.style.use('fivethirtyeight')
# Tweets Natural Language processing and sentiment analysis
#Sentiment analysys porgram 

from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize

# %%
#created app in twitter application 
#generated the keys for access the tweets from twiiter 
consumer_key = "ppwtHVzZDAAstiFOcPyWEic2O"
consumer_secret = "GFjdNDwK1g9qVy6gsBo75MOLEuEuLDopYzJ6kDyGh0PA6QaeRa"
access_token = "1346075457813241856-RQpr4qEitSi1I8QnFYER9vdNohcA9J"
access_secret = "Ztb8S2S4nMx6HuwLcxd5EIXhFZhVwZPl9mQpb5K8Si5wF"
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth)
public_tweets = api.search("Rajinikanth")
public_tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x000001BB83A01C10>, _json={'created_at': 'Tue Jan 05 11:22:25 +0000 2021', 'id': 1346416759004254214, 'id_str': '1346416759004254214', 'text': 'RT @SouthMixMedia1: #NawazuddinSiddiqui About #Thalaivar\n#RajiniKanth #SuperStarRajinikanth \n@rajinikanth @Nawazuddin_S https://t.co/8MK1B0…', 'truncated': False, 'entities': {'hashtags': [{'text': 'NawazuddinSiddiqui', 'indices': [20, 39]}, {'text': 'Thalaivar', 'indices': [46, 56]}, {'text': 'RajiniKanth', 'indices': [57, 69]}, {'text': 'SuperStarRajinikanth', 'indices': [70, 91]}], 'symbols': [], 'user_mentions': [{'screen_name': 'SouthMixMedia1', 'name': 'South Mix Media', 'id': 1260957149695377408, 'id_str': '1260957149695377408', 'indices': [3, 18]}, {'screen_name': 'rajinikanth', 'name': 'Rajinikanth', 'id': 1176135546, 'id_str': '1176135546', 'indices': [93, 105]}, {'screen_name': 'Nawazuddin_S', 'name': 'Nawazuddin Siddiqui', 'id': 1978851349, 'id_str': '1978851349', 'indices': [106, 119]}], 
# ...

# %%
#senntiment analysis
for tweet in public_tweets:
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
# Out:
# RT @SouthMixMedia1: #NawazuddinSiddiqui About #Thalaivar
# #RajiniKanth #SuperStarRajinikanth
# @rajinikanth @Nawazuddin_S https://t.co/8MK1B0…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @kiwitweets_: Appreciation tweet for this Thalaivar Rajinikanth, what an era was this 💯💯 https://t.co/ryVuLhYLCS
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @Memedons_Offl: தேவைப்பட்டால் ஆதரவு கேட்க வேண்டியது... இல்லை என்றால் சங்கி என்று சொல்வது‌ என்ன ஒரு மடத்தனம்
# #Thalaivar #Superstar #Raji…
# Sentiment(polarity=0.0, subjectivity=0.0)
# இப்போ இல்லைனா எப்போவும் இல்ல..
#
# கேள்வியே பதிலானால்....
#
# இப்போ இல்ல
# எப்போவும் இல்ல https://t.co/eusYMNPcuP
# Sentiment(polarity=0.0, subjectivity=0.0)
# @mgspooja @VijayParthiba18 @rajinikanth அதான் ப்ரோ எனக்கும் தெரில அந்த டாக்டர் சார் தான் மொதல்ல ரிலீஸ் பண்ணாரு உடனே… https://t.co/C0oQYUXdlp
# Sentiment(polarity=0.0, subjectivity=0.0)
# @remoboy_offcl @amu_ajay_ @rajinikanth @iamRashmika 😍🤘
# Sentiment(polarity=0.0, subjectivity=0.0)
# ...

# %%
tweets=[]

for i in range(len(public_tweets)):
    t =[]
    t.append(public_tweets[i].text)
    tweets = tweets+t

# %%
#combined tweets
tweets_combiend = " ".join(tweets)

tweets_combined = re.sub('[^A-Za-z0-9]+', ' ',tweets_combiend).lower()


tweets_word= tweets_combined.split()
stop_words = stopwords.words("english")
tweets_words = [w for w in tweets_word if not w in stop_words]

# %%
tweets_words
# Out:
# ['rt',
#  'southmixmedia1',
#  'nawazuddinsiddiqui',
#  'thalaivar',
#  'rajinikanth',
#  'superstarrajinikanth',
#  'rajinikanth',
#  'nawazuddin',
#  'https',
#  'co',
#  '8mk1b0',
#  'rt',
#  'kiwitweets',
#  'appreciation',
#  'tweet',
#  'thalaivar',
#  'rajinikanth',
#  'era',
#  'https',
#  'co',
#  'ryvulhylcs',
#  'rt',
#  'memedons',
#  'offl',
#  'thalaivar',
#  'superstar',
#  'raji',
#  'https',
#  'co',
#  'eusymnpcup',
#  'mgspooja',
#  'vijayparthiba18',
#  'rajinikanth',
#  'https',
#  'co',
#  'c0oqyuxdlp',
#  'remoboy',
#  'offcl',
#  'amu',
#  'ajay',
#  'rajinikanth',
#  'iamrashmika',
#  'rt',
#  'aazimkassim',
#  'toughest',
#  'thalaivar',
#  'rajinikanth',
#  'fan',
#  'honest',
#  'amp',
#  'loyal',
#  'fanbase',
#  'ever',
#  'seen',
#  'rt',
#  'rajinism001',
#  'rajinikanth',
#  'rt',
#  'rajinikanth',
#  'https',
#  'co',
#  'p5jhlxcl14',
#  'https',
#  'co',
#  'g69cwwqivb',
#  'remoboy',
#  'offcl',
#  'level',
#  'headedz',
#  'rajinikanth',
# ...

# %%
with open("C:\\Data science\\Data sets\\TEXT MINING\\stop.txt","r") as sw:
    stop_word = sw.read()
    
  
    tweets_words = [w for w in tweets_words if not w in stop_word]
    
    tweets_Stopwords = " ".join(tweets_words)

# %%
import matplotlib.pylab as plt
from wordcloud import WordCloud

wordcloud_st = WordCloud(
                      background_color='black',
                      width=1800,
                      height=1400
                     ).generate(tweets_Stopwords)
plt.imshow(wordcloud_st)
